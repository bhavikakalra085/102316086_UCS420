# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavikakalra085/102316086_UCS420/blob/main/assignment11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# question 1:

# %% [markdown]
# ![Screenshot 2025-05-03 231156.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-05-03 231256.png](data:image/png;base64,...)

# %% [markdown]
# question 2:

# %% [markdown]
# ![Screenshot 2025-05-03 225325.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-05-03 225833.png](data:image/png;base64,...)
